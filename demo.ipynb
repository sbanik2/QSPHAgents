# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qsph_agent.utils import load_keys_and_config
from qsph_agent.rag_data import build_database_if_needed, load_and_split_database
from qsph_agent.agent_workflow import (
    build_predictor,
    build_qsph_graph,
    make_initial_state,
    summarize_final_state,
)

# %%
# 1) Load keys + config
MP_API_KEY, CONFIG = load_keys_and_config("config.yaml")

# 2) Build / load database
datafile = build_database_if_needed(MP_API_KEY, CONFIG)
train_set, test_set, full_data = load_and_split_database(datafile)

# 3) Build a predictor for classification and regression to get quantitative ranges for the given configuration.
predictor = build_predictor(train_set, n_neighbors=6)

# 4) Pick a test entry
test_key = list(test_set.keys())[0]
test_entry = test_set[test_key]

# 5) Build graph + initial state
graph = build_qsph_graph()
state = make_initial_state(test_entry, train_set, predictor, top_k=7)

# 6) Run the agentic loop
final_state = graph.invoke(state)

# 7) Pretty-print summary
summarize_final_state(final_state)
# Out:
# [Info] Generating database file 'materials.json' for species ['B', 'N']...
# Retrieving SummaryDoc documents:   0%|          | 0/29 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Found 17 materials containing B, N with available DOS
# /Users/sbanik2/opt/anaconda3/lib/python3.12/site-packages/pymatgen/analysis/local_env.py:4019: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   r1 = _get_radius(structure[n])
# /Users/sbanik2/opt/anaconda3/lib/python3.12/site-packages/pymatgen/analysis/local_env.py:4021: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   r2 = _get_radius(entry["site"])
# /Users/sbanik2/opt/anaconda3/lib/python3.12/site-packages/pymatgen/analysis/local_env.py:3933: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   nn_data = self.get_nn_data(structure, n)
# /Users/sbanik2/Desktop/Hackathon/codes/new_Github/qsph_agent/feature_extraction.py:51: UserWarning: Issues encountered while parsing CIF: 8 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   structure = parser.parse_structures(primitive=primitive)[0]
# /Users/sbanik2/Desktop/Hackathon/codes/new_Github/qsph_agent/feature_extraction.py:51: UserWarning: Issues encountered while parsing CIF: 4 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   structure = parser.parse_structures(primitive=primitive)[0]
# /Users/sbanik2/Desktop/Hackathon/codes/new_Github/qsph_agent/feature_extraction.py:51: UserWarning: Issues encountered while parsing CIF: 6 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   structure = parser.parse_structures(primitive=primitive)[0]
# /Users/sbanik2/Desktop/Hackathon/codes/new_Github/qsph_agent/feature_extraction.py:51: UserWarning: Issues encountered while parsing CIF: 3 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   structure = parser.parse_structures(primitive=primitive)[0]
# /Users/sbanik2/Desktop/Hackathon/codes/new_Github/qsph_agent/utils.py:287: UserWarning: Skipping regression model for 'pseudogap_score' due to insufficient non-NaN data (2 samples).
#   warnings.warn(
# Saved database of 17 materials to materials.json
# Train size: 13, Test size: 4
#
# 📌 Target Structure Summary
#
# ╒══════════════════════════════════════════════════════════════════════════╕
# │ Structure Info                                                           │
# ╞══════════════════════════════════════════════════════════════════════════╡
# │ Trigonal B1 N1 (R3m), avg coordination ≈ 3.0, mean bond length ≈ 3.64 Å. │
# ╘══════════════════════════════════════════════════════════════════════════╛
# ╒═══════════════════════════════╤═════════════════════════════════════════════════════════════════╕
# │ Feature                       │ Value                                                           │
# ╞═══════════════════════════════╪═════════════════════════════════════════════════════════════════╡
# │ Material Classification       │ insulating                                                      │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Overall DOS Shape             │ U-shaped DOS around EF.                                         │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Asymmetry Comment             │ Valence side (−1–0 eV) has higher DOS than conduction (0–1 eV). │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Pseudogap Score               │ —                                                               │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Valence Peak (Main Energy)    │ -4.17 eV                                                        │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Valence Peak (Height)         │ 1.18                                                            │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Valence Other Peaks           │ -2.62, -1.06                                                    │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Conduction Peak (Main Energy) │ 4.84 eV                                                         │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Conduction Peak (Height)      │ 0.89                                                            │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────┤
# │ Conduction Other Peaks        │ 5.27                                                            │
# ╘═══════════════════════════════╧═════════════════════════════════════════════════════════════════╛
#
# 🧠 Hypothesized DOS Description (Text)
#
# **Material Classification**: insulating
#   ↳ Reasoning: The query material, B1 N1 in a trigonal R3m structure, closely resembles other nitrides that exhibit insulating behavior, hence expected to be insulating.
# **Overall DOS Shape**: U-shaped DOS around EF
#   ↳ Reasoning: Most structurally similar B-N materials exhibit a U-shaped DOS, indicating a band gap-centered structure.
# **Asymmetry Comment**: Valence side has higher DOS than conduction
#   ↳ Reasoning: As with structurally related materials, valence bands dominate due to p-type orbital predominance in boron nitride, contributing to a higher DOS on the valence side.
# Valence Band peaks at energies: [-3.93 eV, -1.00 eV], with intensities: [2.48, 0.50]
#   ↳ Reasoning: Critique feedback indicated the main valence band peak is at -3.93 eV with higher intensity, aligning with deeper valence states observed in similar B-N materials.
# Conduction Band peaks at energies: [4.50 eV], with intensities: [1.88]
#   ↳ Reasoning: The review of other B-N compounds suggests conduction peaks should initiate just above 4 eV, with stronger than previously predicted intensities, indicating denser states near the conduction band minimum.
# **Pseudogap Score**: None
#   ↳ Reasoning: According to the critique, the pseudogap score is not quantitatively assessed; therefore, it is disregarded until more data confirms its presence.
